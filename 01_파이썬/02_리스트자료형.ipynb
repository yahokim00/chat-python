# %%
odd = [1, 3, 5, 7, 9]

a = []
b = ["life", "is", "too", "short"]
c = [1, 2, "life", "is"]
d = [1, 2, ["life", "is"]]

# %%
a = [1, 2, 3, ["a", "b", "c"]]
a[0]
# Out:
# 1

# %%
a[3]
# Out:
# ['a', 'b', 'c']

# %%
a[-1]
# Out:
# ['a', 'b', 'c']

# %%
# b를 출력하고싶으면
print(a[3][1])
print(a[-1][1])
# Out:
# b
# b

# %%
a =[1, 2, ["a", "b", [ "life", "is"]]]
a[2][2][1]
# Out:
# 'is'

# %%
#슬라이싱 -> 범위를 가져온다
a =[1, 2, 3, 4, 5]
print(a[0:1])
print(a[2:4])
# Out:
# [1]
# [3, 4]

# %%
print(a[0:4])
print(a[:4])
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4]

# %%
print(a[1:5])
print(a[1:])
print(a[:])
# Out:
# [2, 3, 4, 5]
# [2, 3, 4, 5]
# [1, 2, 3, 4, 5]

# %%
# 리스트 더하기
a = [1, 2, 3]
b = [4, 5, 6]

print(a + b)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# 리스트 곱하기
a = [1, 2, 3]
print(a * 3)
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
# 리스트 길이를 구하는 함수
a = [1, 2, 3]
len(a)
# Out:
# 3

# %%
# 리스트 값을 수정하기

a = [1, 2, 3]
a[2] = 4
print(a)
a[1] = 3
print(a)
# Out:
# [1, 2, 4]
# [1, 3, 4]

# %%
# a[3] = 5
# 리스트 범위를 벗어남 -> 3개 밖에 없는데 4번째 값에 넣으라고 해서 그럼

# 리스트 값 추가하기
a.append(5)
print(a)
# Out:
# [1, 3, 4, 5]

# %%
a = sorted(a, reverse=True)
print(a)
# Out:
# [5, 4, 3, 1]

# %%
a.sort()
a.reverse()
a
# Out:
# [5, 4, 3, 1]

# %%
print(a.index(4))
print(a.index(1))
# Out:
# 1
# 3

# %%
a.insert(1, 20000)
print(a)
#자주는 안씀
#append를 더 자주 씀
# Out:
# [5, 20000, 4, 3, 1]

# %%
# 리스트 요소 제거하기 - remove
a.remove(20000)
print(a)

# 위 내용들은 list 일 때 사용할 수 있는 함수들을 공부하는 것임.
# list를 하는 이유는 많이 하기 때문
# Out:
# [5, 4, 3, 1]

# %%
# 리스트 요소 끄집어내기 - pop

a = [5, 4, 3, 2, 1]
result = a.pop()
print(result)
print(a)
# Out:
# 1
# [5, 4, 3, 2]

# %%
a = [5, 4, 3, 2, 1]
result = a.pop(2)
print(result)
# Out:
# 3

# %%
# 리스트 확장 - extend
a = [1, 2, 3]
a.extend([4, 5])
print(a)
# Out:
# [1, 2, 3, 4, 5]
